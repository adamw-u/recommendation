# %%
import tensorflow as tf

# %%
a = tf.constant([[[10, 20], [10, 20]]], name='a')
b = tf.constant([[[2, 3], [2, 3]]], name='b')

# %%
tf.tensordot(a, b, axes=(-1,0))
#tf.matmul(a, b, )

# %%
a

# %%
97/131.0
